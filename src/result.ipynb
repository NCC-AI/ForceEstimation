# %% [markdown]
# - npyで学習は、大差なし、再利用できるので学習が早い
# - モデルの違いはあまり関係なさそうな気もする
# - ReLUに正規化は関係ない、むしろ負の値が消えるから使うべき、線形変換の連続が意味ない件
# - maeのほうが良い結果
#
# - 閾値を超えたらLOSSを二乗するとかやったらどうなるか（Parameterized mae）

# %% [markdown]
# ## Result

# %% [markdown]
# 全体で学習
# 1776.4088261761665

# %% [markdown]
# npyで学習
# 1972.470275668621
# ・初期値のランダムさでちょっと変わるぐらい

# %% [markdown]
# npyで正規化して学習
# 2235.683588256523
# ・最低値のギャップが増えるのはありそう
# ・Dense層にreluはいるのか

# %% [markdown]
# npyで正規化して活性化なしで学習
# 3048.8245033091903
# ・正規化したのに意味なくね？→ReLUに正規化は関係なさそう
# ・意外と大きい値を捉えている

# %% [markdown]
# npyで活性化なしで学習
# 2321.358183382511
# ・まあまあいい感じに捉えている
# ・負の値が出てくる

# %% [markdown]
# npyでlealyReLUで学習
# 2036.1927404806615
# 0.3209635467340261
# ・微妙

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# npyでmaeで学習
# 1732.709693079233
# 0.27312573976658777
# ・くそきれい

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# lstm, mae
# 2801.1193298674825
# 0.44286471618458223
# ・predが終わっている
