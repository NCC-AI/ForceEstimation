# %%
import sys
import os
sys.path.append(os.pardir)

# %%
from fe_dataset import *
from fe_models import *
from fe_evaluate import *
# Out:
# Using TensorFlow backend.

# %%
video_file = '../data/raw/video.mp4'
csv_file = '../data/processed/sparse.csv'
weights = '../data/interim/weights/VGG16_sp.h5'
input_shape = (299, 299, 3)
start_frame = 62000

# %%
modelmaker = ModelMaker(input_shape=input_shape, backbone='VGG16')

# %%
predictor = modelmaker.predictor(weights=weights)

# %%
result = EvaluateModel(video_file, csv_file)

# %%
result.compute_error(input_shape, start_frame, 65000, predictor)
# Out:
# 62225 / 65000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-03d5ed05d68b> in <module>()
# ----> 1 result.compute_error(input_shape, start_frame, 65000, predictor)
#
# ~/ForceEstimation/src/fe_evaluate.py in compute_error(self, input_shape, start_frame, end_frame, model)
#      49             preds.append(pred)
#      50             answers.append(self.gt_f[self.gt_id.index(frame_id)])
# ---> 51             errors.append(np.absolute(self.gt_f[self.gt_id.index(frame_id)] - pred))
#      52             sys.stdout.write("\r%d%s%d" % (frame_id, ' / ', end_frame))
#      53             sys.stdout.flush()
#
# KeyboardInterrupt:

# %%
result.show_result(59)
